# %% [markdown]
# <a href="https://github.com/marinila317-jpg/music-generation-model/blob/master/MusicGen_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Music Generation with MusicGen (AudioCraft) on Google Colab
#
# This notebook allows you to run the Music Generation project, including the Gradio web interface and audio post-processing, directly on Google Colab's free GPU resources. This is ideal for users with less powerful local machines.
#
# ## Instructions:
# 1.  **Run all cells:** Go to `Runtime` -> `Run all` in the Colab menu.
# 2.  **Wait for dependencies to install and model to load.** This might take a few minutes.
# 3.  **Access the Gradio interface:** Once the last cell finishes, a public URL (e.g., `https://xxxx.gradio.app`) will appear. Click on it to open the web interface.
# 4.  **Generate music:** Enter your text prompt, select duration, model version, and post-processing preset (e.g., `dark_ethno_folk`).
#
# **Note:** If you encounter issues, ensure you have selected a GPU runtime (`Runtime` -> `Change runtime type` -> `T4 GPU`).

# %%
# 1. Clone the repository
# !git clone https://github.com/marinila317-jpg/music-generation-model.git
# %cd music-generation-model

# %%
# 2. Install dependencies
# Install ffmpeg for audiocraft
# !apt-get update && apt-get install -y ffmpeg
# Install python packages
# !pip install -r requirements.txt

# %%
# 3. Run the Gradio web interface
# This will provide a public URL to access the interface
# !python app.py
